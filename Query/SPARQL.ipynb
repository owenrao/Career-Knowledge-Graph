# %%
import json
import numpy as np
import pandas as pd
from collections import defaultdict

# %%
df = pd.read_csv("./data/all_titles_processed.csv")
df.iloc[:15, :]
# Out:
#                     id                         name  \
# 0   ET4A446A1A5F6142AD   .NET Application Architect
# 1   ETB5E3860B8B9A9755               .NET Architect
# 2   ETEB3BB8E555C79368               .NET Developer
# 3   ETB3859094FF2DD443     .NET Front End Developer
# 4   ETE906C8A7B45816CC    .NET Full Stack Developer
# 5   ET43E23B0D9CC22B20              .NET Instructor
# 6   ETDC1D7422DAE637FC              .NET Programmer
# 7   ETCA9495C4C34E37FD           .NET SQL Developer
# 8   ET77124BA7E3D9E462            .NET UI Developer
# 9   ET77124BA7E3D9E462            .NET UI Developer
# 10  ET8F077BD6FE1CDADB            1st Grade Teacher
# 11  ET7C32E2610C0AF53C  1st Grade Teacher Assistant
# 12  ET86922DE339DEE480        1st/2nd Grade Teacher
# 13  ET41FCB2FFBAFD7DAD              3D CAD Designer
# 14  ET89058E4C657C1D45          3D Graphic Designer
#
#                                           description  \
# 0   A .NET developer is an information technology ...
# 1   Software architects are expert software design...
# 2   A .NET developer is an information technology ...
# 3   Front end developers implement the visual and ...
# 4   A full stack developer develops and deploys th...
# 5   There are several types of instructor, from dr...
# 6   A .NET developer is an information technology ...
# 7   Also known as a database developer, a SQL (Str...
# 8   A .NET developer is an information technology ...
# 9   Front end developers implement the visual and ...
# 10  Teachers instruct youth on how to acquire ever...
# 11                                                NaN
# 12  Teachers instruct youth on how to acquire ever...
# 13  A CAD designer creates design plans for buildi...
# 14  A graphic designer works as a visual communica...
#
#                                        responsibility  salaryYearly  \
# 0   Designing interfaces for client use\nIdentifyi...      174308.0
# 1   Perform research for projects to determine the...      170168.0
# 2   Designing interfaces for client use\nIdentifyi...      105292.0
# 3   Designing or editing websites or web applicati...       85016.0
# 4   Converting the elements of web designs into ex...      112176.0
# 5   Meeting people to gain an understanding of the...      151329.0
# 6   Designing interfaces for client use\nIdentifyi...      126601.0
# 7   Develop SQL databases including back end data ...      116623.0
# 8   Designing interfaces for client use\nIdentifyi...      116087.0
# 9   Designing or editing websites or web applicati...      116087.0
# 10  Staying up-to-date on information and continui...       46622.0
# 11  Reinforcing lessons that were given previously...           NaN
# 12  Staying up-to-date on information and continui...       50778.0
# 13  Design or redesign complex drawings and layout...       62240.0
# 14  Utilize a variety of media, such as fonts, col...       58677.0
#
#     salaryHourly                                     related_titles  \
# 0            NaN  Enterprise Architect; Systems Architect; Infra...
# 1            NaN  Architectural Drafter; Architectural Designer;...
# 2            NaN  Software Engineer; Software Developer; Front E...
# 3            NaN  Software Engineer; Software Developer; Mobile ...
# 4            NaN  Software Engineer; Software Developer; Front E...
# 5          23.10  Kindergarten Teacher; Substitute Teacher; Elem...
# 6            NaN  Software Engineer; Software Developer; Front E...
# 7            NaN  Oracle Database Administrator; Database Engine...
# 8            NaN  Software Engineer; Software Developer; Mobile ...
# 9            NaN  Software Engineer; Software Developer; Mobile ...
# 10         16.55  Substitute Teacher; Special Education Teacher;...
# 11         14.55                                                NaN
# 12         16.55  Substitute Teacher; Special Education Teacher;...
# 13         24.83  Cad Drafter; CAD Engineer; Mechanical Designer...
# 14         20.16  Visual Designer; Art Director; Web Designer; D...
#
#                                                skills
# 0   .NET, .NET Core, APIs, ASP.NET, AWS, Agile, An...
# 1   Active Directory, Azure, Frameworks, Javascrip...
# 2   .NET, .NET Core, .NET Framework, APIs, ASP Net...
# 3   AJAX, APIs, AWS, Agile, Angular, Azure, Bootst...
# 4   .NET, APIs, AWS, Agile, Angular, Azure, Back E...
# 5   Adult education, Algebra, Bilingual, CPR First...
# 6   .NET, .NET Core, .NET Framework, APIs, ASP Net...
# 7   .NET, APIs, AWS, Agile, Analysis skills, Azure...
# 8   .NET, .NET Core, AJAX, APIs, ASP.NET, AWS, Agi...
# 9   .NET, .NET Core, AJAX, APIs, ASP.NET, AWS, Agi...
# 10  Behavior management, Bilingual, Childcare, Cla...
# 11  Bilingual, Childcare, Classroom experience, Co...
# 12  Behavior management, Bilingual, Childcare, Cla...
# 13  AutoCAD, BIM, CAD, CAD Drafting, Civil enginee...
# 14  Adobe Acrobat, Adobe After Effects, Adobe Crea...

# %%
df[df.related_titles.apply(lambda x: type(x)) == float].name
# Out:
# 11               1st Grade Teacher Assistant
# 50                        AEM Technical Lead
# 101      Accountant/Administrative Assistant
# 106      Accounting Administrative Assistant
# 108                     Accounting Assistant
#                         ...
# 54545         Residential Program Specialist
# 54546         Residential Program Supervisor
# 54547             Residential Program Worker
# 54548            Residential Project Manager
# 54549        Residential Property Consultant
# Name: name, Length: 5726, dtype: object

# %%
print("Null value in Column description:", sum(df.description.apply(lambda x: type(x)) == float))
print("Null value in Column responsibility:", sum(df.responsibility.apply(lambda x: type(x)) == float))
print("Null value in Column related_titles:", sum(df.related_titles.apply(lambda x: type(x)) == float))
print("Null value in Column skills:", sum(df.skills.apply(lambda x: type(x)) == float))
print("Null value in Column salaryHourly:", sum(df.salaryHourly.apply(lambda x: not x >= 0)))
# Out:
# Null value in Column description: 35323
# Null value in Column responsibility: 33271
# Null value in Column related_titles: 5726
# Null value in Column skills: 0
# Null value in Column salaryHourly: 35464

# %%
from rdflib import Graph

# %%
# %%time
graph = Graph()
graph.parse('Career_KG.ttl', format='ttl')
# Out:
# CPU times: user 44.6 s, sys: 810 ms, total: 45.4 s
# Wall time: 45.5 s
# <Graph identifier=N9bc2cc747a5a453681212c8d0a317a0e (<class 'rdflib.graph.Graph'>)>

# %%
# !head -200 Career_KG.ttl
# Out:
# @prefix career: <https://careerkg.com/> .
# @prefix career_skill_category: <https://careerkg.com/skill/category/> .
# @prefix career_skill_type: <https://careerkg.com/skill/type/> .
# @prefix career_title: <https://careerkg.com/title/> .
# @prefix emsi_skill: <https://skills.emsidata.com/skills/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix schema: <https://schema.org/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# career:annualSalary rdfs:subPropertyOf schema:estimatedSalary .
#
# career:hourlySalary rdfs:subPropertyOf schema:estimatedSalary .
#
# career:relatedSkills rdfs:domain schema:Occupation ;
#     rdfs:range career:skill .
#
# career:relatedTitles rdfs:domain schema:Occupation ;
#     rdfs:range schema:Occupation .
#
# career_title:ET000110049ACC0F53 a schema:Occupation ;
#     career:annualSalary "114334.0"^^xsd:float ;
#     career:relatedSkills emsi_skill:BGSB93EA8ABB1E123CDE,
#         emsi_skill:BGSF48FB72EE4F706C58,
#         emsi_skill:ESFA9982A2A945E439CB,
#         emsi_skill:KS1200365FTR9X0M96T9,
#         emsi_skill:KS1203T6J7F2P3TG6Y6K,
#         emsi_skill:KS121056X529461ZF6XW,
#         emsi_skill:KS1212B6QR5SK1LSD4S4,
#         emsi_skill:KS1217P66NK6BW72M9FH,
#         emsi_skill:KS121Z26S4VJLQ1WXN21,
#         emsi_skill:KS122556LMQ829GZCCRV,
#         emsi_skill:KS123K75YYK8VGH90NCS,
#         emsi_skill:KS124JB619VXG6RQ810C,
#         emsi_skill:KS126X663B21NB77ZHSP,
#         emsi_skill:KS127ZG670QJQ7T6K25G,
#         emsi_skill:KS44175745H9Q0DPBDNT,
#         emsi_skill:KS441QM6LTNMGDSQKHLC,
#         emsi_skill:KS7G56T65XR97RXSRBSR,
#         emsi_skill:KSFTJ98A9S38ZAKC5LZY,
#         emsi_skill:KSWG235DLL39IFKXOYFC,
#         emsi_skill:KSZIZ9KL5TCZ43FNUC8U ;
#     career:relatedTitles career_title:ET1F8C3D9FE4D7CB41,
#         career_title:ET43B2A3DB8CFC2A35,
#         career_title:ET5ADBA1104AF3936C,
#         career_title:ETFAB2A289674EEBBB ;
#     schema:description """An account manager is an individual responsible for overseeing the relationship between a business and their customers. They also determine the customers' needs and how the company will deliver on those needs. An account manager usually manages existing customer accounts to create long-term client relationships. Account managers can work in a variety of industries and may also work alongside sales, marketing and customer service associates.
# Account managers are assigned accounts or customers, and serve as a link between their employer and the customer or the account. They stay in close communication with a client and listen to their needs to figure out ways to achieve their objectives. They act as liaisons between clients and departments within their company and convey information and ensure there is mutual understanding and that business is conducted in an accurate and timely manner. Account managers also inform clients about other services and actions that may lead to greater success or satisfaction.. . Account managers monitor a client's budget and explain costs. They negotiate new terms when necessary and provide progress reports to clients and upper management. They stay abreast of trends, changes, and actions by competitors that could impact their clients, and they train junior employees in account servicing. They are assigned clients after salespeople close deals and salespeople brief them on the client's goals and other pertinent information. Account managers assume responsibility for the client from that point on. They foster good relationships with the clients they serve and need a minimum bachelor's degree in business, marketing, communications, public relations, or related fields.""" ;
#     schema:name "National Sales Account Manager" ;
#     schema:responsibilities """Develop and maintain long-term relationships with customer accounts
# Identify new up-selling and cross-selling opportunities within existing accounts
# Manage projects within the clients' account to ensure clients' goals are met
# Act as liaison between customer and business, communicating clients needs and resolving issues
# Collaborate with sales and marketing team to identify new opportunities to grow business""" .
#
# career_title:ET0001DDA0E332BEC2 a schema:Occupation ;
#     career:annualSalary "43952.0"^^xsd:float ;
#     career:relatedSkills emsi_skill:BGSBB98DD44C6391F289,
#         emsi_skill:BGSF48FB72EE4F706C58,
#         emsi_skill:ES335691142D65A7FCD8,
#         emsi_skill:ESFA9982A2A945E439CB,
#         emsi_skill:KS120R375N029L8XGGF6,
#         emsi_skill:KS121056X529461ZF6XW,
#         emsi_skill:KS121Z26S4VJLQ1WXN21,
#         emsi_skill:KS122556LMQ829GZCCRV,
#         emsi_skill:KS1227P6FBK34WLH6X8Z,
#         emsi_skill:KS122CN642J6B9P0384B,
#         emsi_skill:KS122NR6NY1KB0TD40G4,
#         emsi_skill:KS122NY60HCYYDXHQGQN,
#         emsi_skill:KS123K75YYK8VGH90NCS,
#         emsi_skill:KS124JB619VXG6RQ810C,
#         emsi_skill:KS124M967BN188YT05LZ,
#         emsi_skill:KS126HS6R7MH1W08PMVR,
#         emsi_skill:KS126HY6YLTB9R7XJC4Z,
#         emsi_skill:KS127ZG670QJQ7T6K25G,
#         emsi_skill:KS4425C63RPH46FJ9BX7 ;
#     career:relatedTitles career_title:ET4C441ABEF63C429B,
#         career_title:ET901B13CE023A304D,
#         career_title:ETD4A65628D3DCD398,
#         career_title:ETF6F1FB9C327D90AD ;
#     schema:hourlySalary "20.81"^^xsd:float ;
#     schema:name "Travel and Expense Coordinator" .
#
# career_title:ET000250F30CA6B6BD a schema:Occupation ;
#     career:annualSalary "72713.0"^^xsd:float ;
#     career:relatedSkills emsi_skill:BGSF48FB72EE4F706C58,
#         emsi_skill:ES31EB08E14C5E93F4E8,
#         emsi_skill:ES6D4F5379D1F10ABCC2,
#         emsi_skill:ESAC117F714B24AA6831,
#         emsi_skill:ESCF126C496B90BC94B8,
#         emsi_skill:ESFA9982A2A945E439CB,
#         emsi_skill:KS1203W702ND09XHKJR5,
#         emsi_skill:KS120HK5XY6JV257QLTX,
#         emsi_skill:KS1218W78FGVPVP2KXPX,
#         emsi_skill:KS121Z26S4VJLQ1WXN21,
#         emsi_skill:KS122556LMQ829GZCCRV,
#         emsi_skill:KS122C06Z8NDM5G6NYNT,
#         emsi_skill:KS123K75YYK8VGH90NCS,
#         emsi_skill:KS124JB619VXG6RQ810C,
#         emsi_skill:KS127CR6S5TQJVYMG3HB,
#         emsi_skill:KS4425C63RPH46FJ9BX7,
#         emsi_skill:KS7G0PK5YF5GV85CXJSX,
#         emsi_skill:KS8EJ7J5EDY3PHI4WTV8,
#         emsi_skill:KSB305NO1A58IOOYOMNG ;
#     career:relatedTitles career_title:ET4C441ABEF63C429B,
#         career_title:ET69368BFF4499943A,
#         career_title:ET901B13CE023A304D,
#         career_title:ETD4A65628D3DCD398 ;
#     schema:description """A director of operations directs and coordinates activities in an organization. They also keep businesses profitable and cost-effective, from the people to the production. Also known as business operations manager or operations director, the director of operations plays a principal role in setting up and supervising a company's customer retention measures.
# Operations managers ensure a company or organization’s operations run smoothly and on time. They work with people, core operations, budgets, project delivery, and in company strategy. They are responsible for engaging and developing the members of the teams that they manage. Operations managers are involved in financial procedures, including invoicing. They must manage margins, costs, budgeting, and forecasting at the company.. . Operations managers must match individuals to clients’ needs and balance objectives and goals equally from both sides, and they must strive to drive growth strategy and balance global needs. Sometimes they are called upon to support the production planning process or ensure key performance indicators are in place, and production targets are met. Operations managers need a minimum of a bachelor’s degree in business or management or related fields.""" ;
#     schema:name "Director of Spa Operations" ;
#     schema:responsibilities """Play a leading role in compiling company budget, growth and development plans.
# Execute plans to maximize company growth and asset development.
# Create operational strategies to challenge theft and stock losses and put into practice initiatives to reduce significantly company costs.
# Cooperate with the leadership of the company to build an environment of joint obligation and accountability.
# Drive employees and obtain leading performance reviews to ensure a committed and proficient workforce.""" .
#
# career_title:ET0004AFC23172193E a schema:Occupation ;
#     career:annualSalary "72408.0"^^xsd:float ;
#     career:relatedSkills emsi_skill:BGS894FE73CB92723FD8,
#         emsi_skill:ES8447BA722C50F8F852,
#         emsi_skill:ESA9372A0C2E0E70C228,
#         emsi_skill:KS1218W78FGVPVP2KXPX,
#         emsi_skill:KS1220H6CP1BQGH9STNK,
#         emsi_skill:KS122556LMQ829GZCCRV,
#         emsi_skill:KS122ST5X31W4TVGPN0B,
#         emsi_skill:KS122VW78Q67XR4C3ZDW,
#         emsi_skill:KS124G079QNYPLZY6TQL,
#         emsi_skill:KS124JB619VXG6RQ810C,
#         emsi_skill:KS125025Z8ZHJCJMPF7T,
#         emsi_skill:KS1259Z6F890LDXJRXYW,
#         emsi_skill:KS125S36C8SFQ912VYBS,
#         emsi_skill:KS1267F6MSPN366LX7ST,
#         emsi_skill:KS126HY6YLTB9R7XJC4Z,
#         emsi_skill:KS127MG77XGJ4T4R4Y44,
#         emsi_skill:KS1281L64DB6GGCS37X4,
#         emsi_skill:KS440F26FJ79XS9M0QW1,
#         emsi_skill:KS4425C63RPH46FJ9BX7,
#         emsi_skill:KSMJU7BL3K034AD0AQSX ;
#     career:relatedTitles career_title:ET5AD1CE488B4D20AA,
#         career_title:ET5F8A23E938AF6E85,
#         career_title:ETABBAE9948F7A41C0,
#         career_title:ETD3D7CCAFE65E0FFC ;
#     schema:name "Industrial Security Manager" .
#
# career_title:ET000523ABABACBC9A a schema:Occupation ;
#     career:annualSalary "77494.0"^^xsd:float ;
#     career:relatedSkills emsi_skill:BGSF48FB72EE4F706C58,
#         emsi_skill:ES32D9DAFE37545AE8B6,
#         emsi_skill:ESA6D7D7125E22431480,
#         emsi_skill:ESD8BBC24FDAC2815C4E,
#         emsi_skill:KS120HK5XY6JV257QLTX,
#         emsi_skill:KS121F0604D4M03372WW,
#         emsi_skill:KS121Z26S4VJLQ1WXN21,
#         emsi_skill:KS122556LMQ829GZCCRV,
#         emsi_skill:KS1227P6FBK34WLH6X8Z,
#         emsi_skill:KS122D46PJ09YVSBV9DW,
#         emsi_skill:KS123K75YYK8VGH90NCS,
#         emsi_skill:KS1241J6ZY2S66SZG3QS ;
#     career:relatedTitles career_title:ET0BE29836BBD794E2,
#         career_title:ET6647F467E1B1589F,
#         career_title:ET69368BFF4499943A,
#         career_title:ET6E79B4ABD9A6FD21 ;
#     schema:description """An executive chef leads a team of cooks working in a restaurant kitchen. Executive chefs are responsible for managing all activities related to running a kitchen. They work in restaurants of all sizes, from small family-run bistros to massive industrial operations. They plan menus, develop new recipes, supervise kitchen staff, ensure food quality and more. Other names for an executive chef include head chef and chef manager.
# Chefs can be found at the heart of every kitchen. Chefs can be employed by restaurants, hospitals, schools, office complexes, private person or any other place that has a kitchen. A Chef is responsible for the preparation of a wide variety of cuisines. Some Chefs specialize in a particular area of the food industry, and some adopt a variety of styles. The goal of any Chef is to prepare food that is tasty and people enjoy eating. . There are no specific education requirements to hold a position as a Chef. A person's experience and quality of cooking are enough to land a job at most establishments. For higher-profile employment, a degree in culinary arts is highly preferred. These degrees are obtained from local colleges, vocational institutions or dedicated culinary arts schools. Working as a chef can be a high-pressure career. Possessing good organizational and time management skills will ensure success in this field.""" ;
#     schema:name "Area Executive Chef" ;
#     schema:responsibilities """Hire and train new kitchen staff and coordinate and schedule all kitchen staff activities
# Create new menus, source food and equipment vendors and purchase items within a set budget
# Assist with food preparation and inspect the food quality
# Ensure the kitchen meets all sanitation and health codes and upholds food safety regulations
# Keep current on food industry trends and share new techniques with the kitchen staff""" .
#
# career_title:ET00056D09219E40DE a schema:Occupation ;
#     career:annualSalary "37985.0"^^xsd:float ;
#     career:relatedSkills emsi_skill:BGSF48FB72EE4F706C58,
#         emsi_skill:KS121Z26S4VJLQ1WXN21,
#         emsi_skill:KS122556LMQ829GZCCRV ;
#     career:relatedTitles career_title:ET5873F41171BD7810,
#         career_title:ETB04A9FBB2E53FF07,
#         career_title:ETB7CB234A9D4C85BD ;
#     schema:hourlySalary "13.78"^^xsd:float ;
#     schema:name "Game Master" .
#
# career_title:ET0006B003DE68AD96 a schema:Occupation ;
#     career:annualSalary "44049.0"^^xsd:float ;
#     career:relatedSkills emsi_skill:KS120R375N029L8XGGF6,
#         emsi_skill:KS1227P6FBK34WLH6X8Z,
#         emsi_skill:KS123K75YYK8VGH90NCS,
#         emsi_skill:KS124M967BN188YT05LZ,
#         emsi_skill:KS43I7T7CU4Q66EGVQLU,
#         emsi_skill:KS4424S5Z7RZJW427W6B,
#         emsi_skill:KS4425C63RPH46FJ9BX7,
#         emsi_skill:KS7G55M6TRB1N24LW2P5 ;
#     career:relatedTitles career_title:ETA5098F6BA6A1E2C4,
#         career_title:ETB09F03955B740EB6 ;
#     schema:name "Service Center Clerk" .
#
# career_title:ET0006EEBE933C6EF6 a schema:Occupation ;
#     career:annualSalary "88899.0"^^xsd:float ;
#     career:relatedSkills emsi_skill:BGSF48FB72EE4F706C58,
#         emsi_skill:ESBFD4DDD8919551A1EE,

# %% [markdown]
# "Information of [POSITION]",
# "Information of [SKILL]",
# "Related jobs for [POSITION]",
# "Average salary for [POSITION]",
# "JD and responsibility for [POSITION]",
# "Required skills for [POSITION]",
# "Category of [SKILL]",
# "Jobs that have salary range from [MIN] to [MAX]",
# "Jobs that need the most [technical/nontechnical] skills",
# "Skills that belong to category [CATEGORY]",
# "[Language/Non-language] skills",
# "[Software/Non-software] skills"

# %% [markdown]
# ## Info of [POSITION]

# %%
def get_job_info(position, graph):
    res = {"name": position}
    query = """
        SELECT ?title ?jd ?resp ?annual ?hourly (GROUP_CONCAT(DISTINCT ?skillsName; SEPARATOR = ", ") AS ?allSkills) (GROUP_CONCAT(DISTINCT ?relatedNames; SEPARATOR = ", ") AS ?allTitles)
        WHERE {{
            # ?title a schema:Occupation ;
                   schema:name "{}" ;
                   career:relatedSkills ?skills .
            # ?skills schema:name ?skillsName .
            # ?title career:relatedTitles ?relatedTitles .
            # ?relatedTitles schema:name ?relatedNames .
            
            OPTIONAL {{ ?title schema:description ?jd }} .
            OPTIONAL {{ ?title schema:responsibilities ?resp }} .
            OPTIONAL {{ ?title career:annualSalary ?annual }} .
            OPTIONAL {{ ?title career:hourlySalary ?hourly }} .
        }}
        GROUP BY ?title
    """.format(position)
    
    qres = graph.query(query)
    for row in qres:
        res["jobDescription"] = row.jd
        res["responsibility"] = row.resp
        res["requiredSkills"] = row.allSkills.split(", ")
        res["relatedTitles"] = row.allTitles.split(", ")
        res["annualSalary"] = row.annual
        res["hourlySalary"] = row.hourly
        
    return res

# %%
get_job_info("Industrial Security Manager", graph)
# Out:
# {'name': 'Industrial Security Manager',
#  'jobDescription': None,
#  'responsibility': None,
#  'requiredSkills': ['Information Security Audits',
#   'SharePoint Development',
#   'Azure MFA',
#   'Management',
#   'Cloud Computing',
#   'Communications',
#   'Encryption',
#   'Operating Systems',
#   'GOST Standards',
#   'Leadership',
#   'Identity And Access Management',
#   'Intrusion Detection Systems',
#   'Lean Six Sigma',
#   'Project Management',
#   'Microsoft Office',
#   'PCI-X',
#   'Pro Tools',
#   'Security Log',
#   'Written Communication',
#   'AWS SDK'],
#  'relatedTitles': ['Information Security Engineer',
#   'Information Security Specialist',
#   'Security Consultant',
#   'Information Security Analyst'],
#  'annualSalary': rdflib.term.Literal('72408.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float')),
#  'hourlySalary': None}

# %% [markdown]
# ## Info of [SKILL]

# %%
def get_skill_info(skill, graph):
    res = {"name": skill}

    query = """
        SELECT ?skill ?lang ?software (GROUP_CONCAT(DISTINCT ?typeName; SEPARATOR = ", ") AS ?types) (GROUP_CONCAT(DISTINCT ?allCatName; SEPARATOR = ", ") AS ?categories) ?source ?exp
        WHERE {{
            # ?skill a career:skill ;
                   schema:name "{}" ;
                   schema:type ?type ;
                   career:isLanguage ?lang ;
                   career:isSoftware ?software .
            # ?type schema:name ?typeName .
            OPTIONAL {{ ?skill schema:category ?cat .
                        # ?cat schema:object ?allCat .
                        # ?allCat schema:name ?allCatName .}} 
            OPTIONAL {{ ?skill schema:description ?dscp .
                        # ?dscp career:descriptionSource ?source ;
                              schema:object ?exp .}}
        }}
        GROUP BY ?skill
    """.format(skill)

    qres = graph.query(query)
    for row in qres:
        res["type"] = [i.replace("_", " ") for i in row.types.split(", ")]
        res["category"] = [i.replace("_", " ") for i in row.categories.split(", ")]
        res["isLanguage"] = row.lang
        res["isSoftware"] = row.software
        res["source"] = row.source
        res["description"] = row.exp
    
    return res

get_skill_info("Bill Of Materials", graph)
# Out:
# {'name': 'Bill Of Materials',
#  'type': ['Specialized Skill'],
#  'category': ['General Shipping and Receiving',
#   'Transportation, Supply Chain, and Logistics'],
#  'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#  'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#  'source': rdflib.term.URIRef('https://en.wikipedia.org/wiki/Bill_of_materials'),
#  'description': rdflib.term.Literal('A bill of materials or product structure is a list of the raw materials, sub-assemblies, intermediate assemblies, sub-components, parts, and the quantities of each needed to manufacture an end product. A BOM may be used for communication between manufacturing partners or confined to a single manufacturing plant. A bill of materials is often tied to a production order whose issuance may generate reservations for components in the bill of materials that are in stock and requisitions for components that are not in stock. There are two types of bill materials.')}

# %% [markdown]
# ## Related jobs for [POSITION]

# %%
def get_related_jobs(position, graph):
    res = []

    query = """
        SELECT ?relatedNames ?jd ?resp (GROUP_CONCAT(DISTINCT ?skillsName; SEPARATOR = ", ") AS ?allSkills) ?annual ?hourly
        WHERE {{
            # ?title a schema:Occupation ;
                   schema:name "{}" ;
                   career:relatedTitles ?relatedTitles .
            # ?relatedTitles schema:name ?relatedNames ;
                           career:relatedSkills ?skills .
            # ?skills schema:name ?skillsName .
            OPTIONAL {{ ?relatedTitles schema:description ?jd }} .
            OPTIONAL {{ ?relatedTitles schema:responsibilities ?resp }} .
            OPTIONAL {{ ?relatedTitles career:annualSalary ?annual }} .
            OPTIONAL {{ ?relatedTitles career:hourlySalary ?hourly }} .

        }}
        GROUP BY ?relatedTitles
    """.format(position)

    qres = graph.query(query)
    for i, row in enumerate(qres):
        instance = {"relatedJob": row.relatedNames, "jobDescription": row.jd, "responsibility": row.resp, 
                    "requiredSkills": row.allSkills.split(", "), "annualSalary": row.annual, "hourlySalary": row.hourly}
        res.append(instance)
    
    return res

# %%
get_related_jobs("Full Cycle Recruiter", graph)
# Out:
# [{'relatedJob': rdflib.term.Literal('IT Recruiter'),
#   'jobDescription': None,
#   'responsibility': None,
#   'requiredSkills': ['AtScale (Software)',
#    'Microsoft Excel',
#    'Communications',
#    'Microsoft Office',
#    'Recruiting Concepts',
#    'Resourcing'],
#   'annualSalary': rdflib.term.Literal('81752.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float')),
#   'hourlySalary': None},
#  {'relatedJob': rdflib.term.Literal('Recruitment Consultant'),
#   'jobDescription': None,
#   'responsibility': None,
#   'requiredSkills': ['B2B Advertising',
#    'Job Descriptions',
#    'Strong Work Ethic',
#    'Applicant Tracking Systems',
#    'Communications',
#    'Consulting',
#    'Sales',
#    'Subsidies',
#    'Leadership',
#    'Pipeline Pilot',
#    'Recruiting Concepts',
#    'S Interface',
#    'Time Management',
#    'Mentoring Youth'],
#   'annualSalary': rdflib.term.Literal('77598.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float')),
#   'hourlySalary': None},
#  {'relatedJob': rdflib.term.Literal('Corporate Recruiter'),
#   'jobDescription': rdflib.term.Literal("A corporate recruiter, also known as a professional in talent acquisition or a human resource recruiter, is an individual who helps a company in the recruitment process of new hires. A corporate recruiter reviews resumes, conducts initial interviews and evaluates candidates' skills to find the right fit for open positions in small and large companies.\nA corporate recruiter is responsible for filling open positions for an organization. They conduct the process from the stage of locating potential applicants via various sources, such as social media or resume banks, to interviewing and offering positions to qualified applicants. Corporate recruiters often specialize in one job field, such as information technology, and recruit only candidates from this area. To find recruits, some corporate recruiters travel to job fairs or attend networking events.. . Corporate recruiters usually have a background in human resources (HR) and often possess a bachelor's degree in business or HR. A recruiter may also pursue certifications, after working for at least one year in the role, from the Society for Human Resource Management (SHRM). Successful workers in this industry have strong verbal and written communication skills, the ability to weigh multiple variables to make important decisions, and have a good sense of character."),
#   'responsibility': rdflib.term.Literal("Establishing and maintaining professional relationships with local organizations and colleagues.\nApplying principles of behavioral interviewing in assessment of the candidates' qualifications.\nScreening resumes and interviewing candidates for open positions.\nCreating job listings that outline requirements for each position.\nUsing online job posting boards and databases to locate qualified, potential candidates."),
#   'requiredSkills': ['Outlook Add-Ins',
#    'Computer Sales',
#    'AtScale (Software)',
#    'Interviewing Skills',
#    'Human Resource Strategy',
#    'Onboarding Strategies',
#    'Microsoft Excel',
#    'Applicant Tracking Systems',
#    'Attenuation',
#    'Customer Service',
#    'Communications',
#    'Control Communications',
#    'Data Mining',
#    'Interpersonal Communications',
#    'Microsoft Outlook',
#    'Microsoft Office',
#    'Written Communication',
#    'Resourcing',
#    'Hybris'],
#   'annualSalary': rdflib.term.Literal('88178.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float')),
#   'hourlySalary': None},
#  {'relatedJob': rdflib.term.Literal('Technical Recruiter'),
#   'jobDescription': None,
#   'responsibility': None,
#   'requiredSkills': ['Talent Sourcing',
#    'Strong Work Ethic',
#    'Applicant Tracking Systems',
#    'Control Communications',
#    'Diversity Combining',
#    'Microsoft Office',
#    'Negotiation',
#    'Pipeline Pilot'],
#   'annualSalary': rdflib.term.Literal('76571.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float')),
#   'hourlySalary': None}]

# %% [markdown]
# ## Average Salary for [POSITION]

# %%
def get_job_salary(position, graph):
    res = {"name": position}
    query = """
        SELECT ?title ?annual ?hourly
        WHERE {{
            # ?title a schema:Occupation ;
                   schema:name "{}" ;
            
            OPTIONAL {{ ?title career:annualSalary ?annual }} .
            OPTIONAL {{ ?title career:hourlySalary ?hourly }} .

        }}
    """.format(position)
    
    qres = graph.query(query)
    for i, row in enumerate(qres):
        res["annualSalary"] = row.annual
        res["hourlySalary"] = row.hourly
        
    return res

# %%
get_job_salary("Managing Director of Finance", graph)
# Out:
# {'name': 'Managing Director of Finance',
#  'annualSalary': rdflib.term.Literal('317592.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float')),
#  'hourlySalary': None}

# %% [markdown]
# ## JD and responsibility for [POSITION]

# %%
def get_job_dscp_resp(position, graph):
    res = {"name": position}
    query = """
        SELECT ?title ?jd ?resp
        WHERE {{
            # ?title a schema:Occupation ;
                   schema:name "{}" .
            OPTIONAL {{ ?title schema:description ?jd }} .
            OPTIONAL {{ ?title schema:responsibilities ?resp }} .
        }}
    """.format(position)
    
    qres = graph.query(query)
    for i, row in enumerate(qres):
        res["jobDescription"] = row.jd
        res["responsibility"] = row.resp

    return res

# %%
get_job_dscp_resp("Office Manager/Dispatcher", graph)
# Out:
# {'name': 'Office Manager/Dispatcher',
#  'jobDescription': rdflib.term.Literal("An office manager provides organization and oversight to the administrative team within a department or company by providing tools and resources for employees to be more efficient. They often report to senior management or the CEO of a company. In small companies, an office manager might also provide administrative support.\nOffice managers coordinate and oversee administrative duties in an office, and ensure that the office operates efficiently and smoothly. Their responsibilities generally include duties like greeting visitors, managing office supplies, overseeing other administrative staff, owning budgets, and supporting staff with administrative tasks like scheduling meetings.. . Office managers typically have a Bachelor's degree in business administration, communications, or in a related field. However, for some office manager positions a high school diploma is sufficient. Office managers need to be highly organized and self-motivated, and they typically have excellent attention to detail."),
#  'responsibility': rdflib.term.Literal('Working with management on marketing\nDeveloping budgets\nProviding weekly and monthly financial reports\nManaging office support personnel\nMaintaining office equipment and troubleshooting problems\nCompleting new employee orientation\nCompleting administrative employee reviews\nDeveloping and implementing efficient office procedures')}

# %% [markdown]
# ## Required skills for [POSITION]

# %%
def get_job_skills(position, graph):
    res = []
    query = """
        SELECT ?skills ?skillsName ?lang ?software  (GROUP_CONCAT(DISTINCT ?typeName; SEPARATOR = ", ") AS ?types) (GROUP_CONCAT(DISTINCT ?allCatName; SEPARATOR = ", ") AS ?categories) ?source ?exp
        WHERE {{
            # ?title a schema:Occupation ;
                   schema:name "{}" ;
                   career:relatedSkills ?skills .
            # ?skills schema:name ?skillsName ;
                    schema:type ?type ;
                    career:isLanguage ?lang ;
                    career:isSoftware ?software .
            # ?type schema:name ?typeName .
            OPTIONAL {{ ?skills schema:category ?cat .
                        # ?cat schema:object ?allCat .
                        # ?allCat schema:name ?allCatName . }} 
            OPTIONAL {{ ?skills schema:description ?dscp .
                        # ?dscp career:descriptionSource ?source ;
                              schema:object ?exp . }}
        }}
        GROUP BY ?skills
    """.format(position)
    
    qres = graph.query(query)
    for i, row in enumerate(qres):
        instance = {}
        instance["skill"] = row.skillsName
        instance["type"] = [i.replace("_", " ") for i in row.types.split(", ")]
        instance["category"] = [i.replace("_", " ") for i in row.categories.split(", ")]
        instance["isLanguage"] = row.lang
        instance["isSoftware"] = row.software
        instance["source"] = row.source
        instance["description"] = row.exp
        res.append(instance)
        
    return res

# %%
# %%time
get_job_skills("Recreational Services Director", graph)
# Out:
# CPU times: user 30.7 ms, sys: 729 µs, total: 31.4 ms
# Wall time: 31.2 ms
# [{'skill': rdflib.term.Literal('Computer Sales'),
#   'type': ['Specialized Skill'],
#   'category': ['Sales', 'Specialized Sales'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': None,
#   'description': None},
#  {'skill': rdflib.term.Literal('Administrative Agencies'),
#   'type': ['Specialized Skill'],
#   'category': ['Law, Regulation, and Compliance',
#    'Regulation and Legal Compliance'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': None,
#   'description': None},
#  {'skill': rdflib.term.Literal('Agile Product Management'),
#   'type': ['Specialized Skill'],
#   'category': ['Business', 'Product Management'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': rdflib.term.URIRef('https://en.wikipedia.org/wiki/Agile_management'),
#   'description': rdflib.term.Literal('Agile management is the application of the principles of Agile software development to various management processes, particularly project management. Following the appearance of the Manifesto for Agile Software Development in 2001, Agile techniques started to spread into other areas of activity. In 2004, one of the authors of the original manifesto, Jim Highsmith, published Agile Project Management: Creating Innovative Products.')},
#  {'skill': rdflib.term.Literal('Agile Software Development'),
#   'type': ['Specialized Skill'],
#   'category': ['Agile Software Development', 'Information Technology'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': rdflib.term.URIRef('https://en.wikipedia.org/wiki/Agile_software_development'),
#   'description': rdflib.term.Literal('In software development, agile practices involve discovering requirements and developing solutions through the collaborative effort of self-organizing and cross-functional teams and their customer(s)/end user(s). It advocates adaptive planning, evolutionary development, early delivery, and continual improvement, and it encourages flexible responses to change.')},
#  {'skill': rdflib.term.Literal('Analytical Skills'),
#   'type': ['Common Skill'],
#   'category': ['General Science and Research', 'Science and Research'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': rdflib.term.URIRef('https://en.wikipedia.org/wiki/Analytical_skill'),
#   'description': rdflib.term.Literal('Analytical skill is the ability to deconstruct information into smaller categories in order to draw conclusions. Analytical skill consists of categories that include logical reasoning, critical thinking, communication, research, data analysis and creativity. Analytical skill is taught in contemporary education with the intention of fostering the appropriate practises for future professions. The professions that adopt analytical skill include educational institutions, public institutions, community organisations and industry.')},
#  {'skill': rdflib.term.Literal('Agile Testing'),
#   'type': ['Specialized Skill'],
#   'category': ['Agile Software Development', 'Information Technology'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': rdflib.term.URIRef('https://en.wikipedia.org/wiki/Agile_testing'),
#   'description': rdflib.term.Literal('Agile testing is a software testing practice that follows the principles of agile software development. Agile testing involves all members of a cross-functional agile team, with special expertise contributed by testers, to ensure delivering the business value desired by the customer at frequent intervals, working at a sustainable pace. Specification by example is used to capture examples of desired and undesired behavior and guide coding.')},
#  {'skill': rdflib.term.Literal('Budgeting'),
#   'type': ['Common Skill'],
#   'category': ['Budget Management', 'Finance'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': rdflib.term.URIRef('https://en.wikipedia.org/wiki/Budgeting'),
#   'description': rdflib.term.Literal('A budget is a financial plan for a defined period, often one year. It may also include planned sales volumes and revenues, resource quantities, costs and expenses, assets, liabilities, and cash flows. Companies, governments, families, and other organizations use it to express strategic plans of activities or events in measurable terms.')},
#  {'skill': rdflib.term.Literal('Business Development'),
#   'type': ['Specialized Skill'],
#   'category': ['Business', 'Business Strategy'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': rdflib.term.URIRef('https://en.wikipedia.org/wiki/Business_development'),
#   'description': rdflib.term.Literal('Business development entails tasks and processes to develop and implement growth opportunities within and between organizations. It is a subset of the fields of business, commerce and organizational theory. Business development is the creation of long-term value for an organization from customers, markets, and relationships. Business development can be taken to mean any activity by either a small or large organization, non-profit or for-profit enterprise which serves the purpose of ‘developing’ the business in some way. In addition, business development activities can be done internally or externally by a business development consultant. External business development can be facilitated through Planning Systems, which are put in place by governments to help small businesses. In addition, reputation building has also proven to help facilitate business development.')},
#  {'skill': rdflib.term.Literal('Customer Service'),
#   'type': ['Common Skill'],
#   'category': ['Customer Service', 'Customer and Client Support'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': rdflib.term.URIRef('https://en.wikipedia.org/wiki/Customer_service'),
#   'description': rdflib.term.Literal('Customer service is the provision of service to customers before, during, and after a purchase. The perception of success of such interactions is dependent on employees "who can adjust themselves to the personality of the guest".\nCustomer service concerns the priority an organization assigns to customer service relative to components such as product innovation and pricing. In this sense, an organization that values good customer service may spend more money in training employees than the average organization or may proactively interview customers for feedback.')},
#  {'skill': rdflib.term.Literal('Communications'),
#   'type': ['Common Skill'],
#   'category': ['Communication', 'Media and Communications'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': rdflib.term.URIRef('https://en.wikipedia.org/wiki/Communication'),
#   'description': rdflib.term.Literal('Communication is the act of developing meaning among entities or groups through the use of sufficiently mutually understood signs, symbols, and semiotic conventions.')},
#  {'skill': rdflib.term.Literal('Control Communications'),
#   'type': ['Specialized Skill'],
#   'category': ['Information Technology', 'Systems Administration'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': rdflib.term.URIRef('https://en.wikipedia.org/wiki/Control_communications'),
#   'description': rdflib.term.Literal('In telecommunication, control communications is the branch of technology devoted to the design, development, and application of communications facilities used specifically for control purposes, such as for controlling (a) industrial processes, (b) movement of resources, (c) electric power generation, distribution, and utilization, (d) communications networks, and (e) transportation systems.')},
#  {'skill': rdflib.term.Literal('Data Collection'),
#   'type': ['Specialized Skill'],
#   'category': ['Data Collection', 'Information Technology'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': rdflib.term.URIRef('https://en.wikipedia.org/wiki/Data_collection'),
#   'description': rdflib.term.Literal('Data collection is the process of gathering and measuring information on targeted variables in an established system, which then enables one to answer relevant questions and evaluate outcomes. Data collection is a research component in all study fields, including physical and social sciences, humanities, and business. While methods vary by discipline, the emphasis on ensuring accurate and honest collection remains the same. The goal for all data collection is to capture quality evidence that allows analysis to lead to the formulation of convincing and credible answers to the questions that have been posed.Data collection and validation consists of four steps when it involves taking a census and seven steps when it involves sampling')},
#  {'skill': rdflib.term.Literal('English Language'),
#   'type': ['Common Skill'],
#   'category': ['Language Competency', 'Media and Communications'],
#   'isLanguage': rdflib.term.Literal('true', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': rdflib.term.URIRef('https://en.wikipedia.org/wiki/English_language'),
#   'description': rdflib.term.Literal('English is a West Germanic language first spoken in early medieval England, which has eventually become the leading language of international discourse in the 21st century. It is named after the Angles, one of the ancient Germanic peoples that migrated to the area of Great Britain that later took their name, England. Both names derive from Anglia, a peninsula on the Baltic Sea. English is most closely related to Frisian and Low Saxon, while its vocabulary has been significantly influenced by other Germanic languages, particularly Old Norse, as well as Latin and French.')},
#  {'skill': rdflib.term.Literal('Epic Cadence'),
#   'type': ['Specialized Skill'],
#   'category': ['Health Care', 'Health Care Administration'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('true', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': None,
#   'description': None},
#  {'skill': rdflib.term.Literal('Leadership'),
#   'type': ['Common Skill'],
#   'category': ['Initiative and Leadership', 'Physical and Inherent Abilities'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': rdflib.term.URIRef('https://en.wikipedia.org/wiki/Leadership'),
#   'description': rdflib.term.Literal('Leadership is both a research area, and a practical skill encompassing the ability of an individual, group or organization to "lead", influence or guide other individuals, teams, or entire organizations. Often viewed as a contested term, specialist literature debates various viewpoints, contrasting Eastern and Western approaches to leadership, and also North American versus European approaches.')},
#  {'skill': rdflib.term.Literal('Effective Coach'),
#   'type': ['Common Skill'],
#   'category': ['Initiative and Leadership', 'Physical and Inherent Abilities'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': None,
#   'description': None},
#  {'skill': rdflib.term.Literal('Contract Of Sale'),
#   'type': ['Specialized Skill'],
#   'category': ['Business', 'Contract Management'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': rdflib.term.URIRef('https://en.wikipedia.org/wiki/Contract_of_sale'),
#   'description': rdflib.term.Literal('A contract of sale, sales contract, sales order, or contract for sale is a legal contract for the purchase of assets by a buyer from a seller for an agreed upon value in money.')},
#  {'skill': rdflib.term.Literal('Written Communication'),
#   'type': ['Common Skill'],
#   'category': ['Communication', 'Media and Communications'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': None,
#   'description': None},
#  {'skill': rdflib.term.Literal('Evaluating Staff'),
#   'type': ['Common Skill'],
#   'category': ['Human Resources', 'Human Resources Management and Planning'],
#   'isLanguage': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'isSoftware': rdflib.term.Literal('false', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean')),
#   'source': None,
#   'description': None}]

# %% [markdown]
# ## Category of [SKILL]

# %%
def get_skill_cat(skill, graph):
    res = {}

    query = """
        SELECT ?skill (GROUP_CONCAT(DISTINCT ?typeName; SEPARATOR = ", ") AS ?types) (GROUP_CONCAT(DISTINCT ?allCatName; SEPARATOR = ", ") AS ?categories)
        WHERE {{
            # ?skill a career:skill ;
                   schema:name "{}" ;
                   schema:type ?type .
            # ?type schema:name ?typeName .
            OPTIONAL {{ ?skill schema:category ?cat .
                        # ?cat schema:object ?allCat .
                        # ?allCat schema:name ?allCatName .}} 
        }}
        GROUP BY ?skill
    """.format(skill)

    qres = graph.query(query)
    for row in qres:
        res["type"] = [i.replace("_", " ") for i in row.types.split(", ")]
        res["category"] = [i.replace("_", " ") for i in row.categories.split(", ")]
        
    return res

get_skill_cat("Bill Of Materials", graph)
# Out:
# {'type': ['Specialized Skill'],
#  'category': ['General Shipping and Receiving',
#   'Transportation, Supply Chain, and Logistics']}

# %% [markdown]
# ## Job salary range from [MIN] to [MAX]

# %%
# add skills -> 4min running time
def get_job_with_range(keyword, lower, upper, graph):
    res = []
    query = """
        SELECT ?title ?name ?jd ?resp ?annual #?hourly (GROUP_CONCAT(DISTINCT ?skillsName; SEPARATOR = ", ") AS ?allSkills)
        WHERE {{
            # ?title a schema:Occupation ;
                   schema:name ?name .
                   #career:relatedSkills ?skills .
            #?skills schema:name ?skillsName .
            
            OPTIONAL {{ ?title schema:description ?jd }} .
            OPTIONAL {{ ?title schema:responsibilities ?resp }} .
            OPTIONAL {{ ?title career:annualSalary ?annual }} .
            #OPTIONAL {{ ?title career:hourlySalary ?hourly }} .
                        
            FILTER (CONTAINS(LCASE(?name), "{}")) .
            FILTER (?annual >= {} && ?annual <= {}) .
        }}
    """.format(keyword.lower(), lower, upper)
    
    qres = graph.query(query)
    for row in qres:
        instance = {}
        instance["name"] = row.name
        instance["jobDescription"] = row.jd
        instance["responsibility"] = row.resp
        #instance["Required Skills"] = row.allSkills.split(", ")
        instance["annualSalary"] = row.annual
        #instance["Hourly Salary"] = row.hourly
        res.append(instance)
    return res

# %%
# %%time
get_job_with_range("engineer", 99000, 99500, graph)
# Out:
# CPU times: user 13.8 s, sys: 24.2 ms, total: 13.9 s
# Wall time: 13.9 s
# [{'name': rdflib.term.Literal('Transportation Engineer/Project Manager'),
#   'jobDescription': None,
#   'responsibility': None,
#   'annualSalary': rdflib.term.Literal('99164.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('System Planning Engineer'),
#   'jobDescription': None,
#   'responsibility': None,
#   'annualSalary': rdflib.term.Literal('99397.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Electrical Integration Engineer'),
#   'jobDescription': None,
#   'responsibility': None,
#   'annualSalary': rdflib.term.Literal('99354.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Technical Implementation Engineer'),
#   'jobDescription': rdflib.term.Literal("Engineers use mathematical and scientific principles to provide efficient solutions to technical problems. While scientists deliver scientific innovations, engineers are the ones who make these innovations useful for societal and consumer needs.\nSystems administrators are responsible for the setup and maintenance of a company or organization’s computer systems. They ensure a computer within a company's network, and especially the server, is operating smoothly and securely. Systems administrators configure and maintain a network computer system that includes hardware system software and applications.. . Systems administrators ensure data is securely stored and perform regular backups of the data and information. They diagnose and resolve any hardware, software, networking, or system issues that arise and replace and upgrade any defective or outdated components if appropriate. They monitor systems’ performance to ensure they are functioning smoothly and securely and research and recommend new approaches to improve the network computer system if requested. They provide technical support to employees and personnel, and document the processes employees need to follow to work within a computing system. Systems administrators need relevant degrees, including a bachelor's degree in computer science or a relevant field, a diploma in information systems or information technology, and familiarity with SQL and database operations."),
#   'responsibility': rdflib.term.Literal('Development of new products such as helicopters, aero planes, toys, power plants, computers and chemicals\nSupervision of production in factories and testing products from factories to maintain quality standards\nEstimation of the time and price required to finish projects\nUse of computers to create and evaluate designs\nDetermination of the failures of components in factories'),
#   'annualSalary': rdflib.term.Literal('99157.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Cybersecurity Engineer'),
#   'jobDescription': rdflib.term.Literal('Engineers use mathematical and scientific principles to provide efficient solutions to technical problems. While scientists deliver scientific innovations, engineers are the ones who make these innovations useful for societal and consumer needs.\nInformation security engineers plan, design, build, and integrate tools and systems that are used to protect electronic information and devices. They implement systems to collect information about security incidents and outcomes. They may develop metrics or procedures for evaluating the effectiveness of the systems and tactics being used, and may also be involved in creating training materials. They also often build the infrastructure to support these systems and processes.. . Information security engineers typically have a bachelor’s degree in a computer science discipline, along with a background in the IT field. They must have extensive experience with programming languages and tools, and be comfortable using script writing languages. Experience working with a variety of automation tools, firewall systems, and other technologies used for cybersecurity roles are helpful.'),
#   'responsibility': rdflib.term.Literal('Development of new products such as helicopters, aero planes, toys, power plants, computers and chemicals\nSupervision of production in factories and testing products from factories to maintain quality standards\nEstimation of the time and price required to finish projects\nUse of computers to create and evaluate designs\nDetermination of the failures of components in factories'),
#   'annualSalary': rdflib.term.Literal('99353.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Energy Project Engineer'),
#   'jobDescription': rdflib.term.Literal("A project engineer is in charge of a company's technical and engineering projects. This includes oversight of project personnel, costs and scheduling. Their aim is to bring every project in on budget and time. A project engineer may also be called a field engineer, construction engineer or construction project engineer.\nProject engineers manage teams throughout the entire span of a project which is technical or involves engineering. They ensure the design, consistency and functionality of a project throughout its entire process. They prepare, schedule, coordinate and monitor all assigned projects and communicate during daily interactions with clients to interpret requirements and needs.. . Project engineers communicate with the project manager and other members of the team to provide any necessary assistance or technical support. They review the engineering deliverables and initiate appropriate corrective actions throughout the duration of the project. They prepare schedules, and coordinate and monitor the assigned engineering projects. They monitor compliance to applicable codes and practices as well as quality assurance and quality control policies. They strive to prepare, schedule, coordinate, and monitor the project to ensure it adheres to its budget. Project engineers need a bachelor’s degree in engineering, business management, or construction management."),
#   'responsibility': rdflib.term.Literal("Lead and manage a team of professionals and offer guidance on overall project strategy\nDevelop, manage and stick to a budget\nCommunicate with senior levels of management about the project's development\nTroubleshoot problems on-site and remain calm when they happen\nKnow what sort of people you want to work on your site and hire appropriately"),
#   'annualSalary': rdflib.term.Literal('99322.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Systems Administrator/Engineer'),
#   'jobDescription': None,
#   'responsibility': None,
#   'annualSalary': rdflib.term.Literal('99387.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Engineer/Project Manager'),
#   'jobDescription': None,
#   'responsibility': None,
#   'annualSalary': rdflib.term.Literal('99164.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Information Assurance Engineer'),
#   'jobDescription': rdflib.term.Literal('Engineers use mathematical and scientific principles to provide efficient solutions to technical problems. While scientists deliver scientific innovations, engineers are the ones who make these innovations useful for societal and consumer needs.\nInformation security engineers plan, design, build, and integrate tools and systems that are used to protect electronic information and devices. They implement systems to collect information about security incidents and outcomes. They may develop metrics or procedures for evaluating the effectiveness of the systems and tactics being used, and may also be involved in creating training materials. They also often build the infrastructure to support these systems and processes.. . Information security engineers typically have a bachelor’s degree in a computer science discipline, along with a background in the IT field. They must have extensive experience with programming languages and tools, and be comfortable using script writing languages. Experience working with a variety of automation tools, firewall systems, and other technologies used for cybersecurity roles are helpful.'),
#   'responsibility': rdflib.term.Literal('Development of new products such as helicopters, aero planes, toys, power plants, computers and chemicals\nSupervision of production in factories and testing products from factories to maintain quality standards\nEstimation of the time and price required to finish projects\nUse of computers to create and evaluate designs\nDetermination of the failures of components in factories'),
#   'annualSalary': rdflib.term.Literal('99165.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Java Application Engineer'),
#   'jobDescription': rdflib.term.Literal('An application developer is an information technology professional who uses their knowledge of computer systems and programming languages to create user-friendly software applications for computers, mobile devices and other technologies. These professionals can find employment in multiple industries, as the rise in technological use has greatly influenced the business world.\nApplications engineers work as a bridge between customers and engineering teams. They use customer input and sales information to design or redesign, develop, test, and implement complex software problems and applications. They provide technical support and expertise to customers by testing applications and responding to feedback. They perform installations and maintenance and often perform sales presentations and demonstrations.. . Applications engineers perform customer analysis to create applications that respond to their needs and provide innovative solutions to common problems. They perform prototyping applications and code reviews to ensure products are satisfactory. They debug, test, code, improve, and redesign tasks, respond to customer issues, provide updated software that solves bug issues, perform customer installations, and work with customer service teams. Applications engineers need a degree in software engineering.'),
#   'responsibility': rdflib.term.Literal("Use results of marketing research to create user-friendly applications.\nCreate upgrades for previously developed applications.\nConsult with customers for desired changes in an app's design.\nPerform maintenance tests on existing software.\nStay updated on new industry software."),
#   'annualSalary': rdflib.term.Literal('99311.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Manufacturing Process Engineer'),
#   'jobDescription': rdflib.term.Literal('Process engineers work for a variety of manufacturing companies to develop the industrial processes that create safe food, chemicals, medicines and other products. Process engineers develop the chemical processes used in manufacturing. Process engineers work at diverse sites such as laboratories and similar facilities to ensure manufacturing procedures and equipment are safe and working properly.\nProcess engineers are responsible for providing the chemical or biochemical processes and equipment that ultimately extract materials from their raw states and transform them into a beneficial or saleable end product. They are also responsible for the design, implementation, control, and optimization of the product’s industrial processing phase, and they usher the product along from start to finish.. . Process engineers often function as the point persons for or during the continuous processes commonly found in the chemical, petrochemical, agricultural, and mineral processing sectors. They also work in this capacity with advanced materials found within the food, pharmaceutical, and biotechnology industries. They create set specifications for the raw materials, and develop, implement, and monitor the equipment in use and the process of the materials and the manufacturing systems. They can also work in sales or design, and they sometimes work for the optimization of the sales and software processes. Process engineers need a bachelor’s degree in chemical, manufacturing, or industrial engineering. For senior positions, employers will require advanced or master’s degrees in the same subjects.'),
#   'responsibility': rdflib.term.Literal('Do research and collect data to analyze areas for design processes for optimizing productivity.\nOversee facility operations, maintenance and implementation of improved manufacturing processes.\nExamine processes and suggest improvements to processes.\nInvestigate and fix problems with manufacturing processes, procedures and operations.\nWrite reports to document problems, solutions and actions and communicate findings.'),
#   'annualSalary': rdflib.term.Literal('99064.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Staff Supplier Quality Engineer'),
#   'jobDescription': rdflib.term.Literal("A quality engineer ensures engineering and other manufacturing processes perform smoothly and effectively. They investigate potential problems in tool usage, process management and materials and find solutions. Quality engineers work in factories and laboratories of industries such as food, textiles and computers. Their efforts not only help improve working conditions for employees but in some areas, legal requirements demand it.\nA quality engineer is responsible for the generation of a strategic plan to improve the business processes and increase production output. Duties include creating the company's quality standards and testing systems to reflect efficiency, reliability and performance. Quality engineers are also responsible for the creation of documentation that reports issues and errors relating to the production process with efforts placed to find a solution. Depending on the industry and organization, the typical career advancement for a quality engineer is in a managerial or executive position.. . A bachelor's degree in engineering or a related field is often required for the job of a quality engineer with most companies expressing a preference for a master's degree. A successful track record working as a quality engineer is also often required by hiring managers. Other valuable skills include a high proficiency in computer technology including Microsoft Office applications and strong analytical and problem-solving skills."),
#   'responsibility': rdflib.term.Literal('Develop and implement standards of quality and control systems\nMonitor and analyze employee performance\nInspect and test assets such as equipment, materials and processes\nCollaborate with management on solutions for improvement\nReview codes, laws and other standards required in a particular industry'),
#   'annualSalary': rdflib.term.Literal('99111.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('PKI Engineer'),
#   'jobDescription': rdflib.term.Literal("Engineers use mathematical and scientific principles to provide efficient solutions to technical problems. While scientists deliver scientific innovations, engineers are the ones who make these innovations useful for societal and consumer needs.\nEngineers are highly skilled specialists who use math and science to solve both simple and complex everyday problems. They make use of new discoveries by taking relevant information from prior scientific discoveries and finding where they apply to the more practical settings and uses. Engineers' valuable innovations strive to advance the way humans utilize products or perform tasks. Engineers are the professionals directly involved in the invention, design, and the maintenance of various machines, structures, or data systems.. . Engineers work with various objects and items, from massive construction project work sites to lending their expertise to development of the human genome. Often, they are responsible for the innovation and developments of new products or services, or a new type of technology or process. Engineers use science, technology, or math to solve problems and design machinery, build skyscrapers, and oversee public works. They also address society's needs and problems, including preserving clean water, development of drug delivery systems that work inside cells, or cleaning up oil spills. Engineers need a bachelor’s degree in engineering from a school accredited by the Accreditation Board for Engineering and Technology and must pass the Fundamentals of Engineering and the Principles and Practice of Engineering exams"),
#   'responsibility': rdflib.term.Literal('Development of new products such as helicopters, aero planes, toys, power plants, computers and chemicals\nSupervision of production in factories and testing products from factories to maintain quality standards\nEstimation of the time and price required to finish projects\nUse of computers to create and evaluate designs\nDetermination of the failures of components in factories'),
#   'annualSalary': rdflib.term.Literal('99143.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('HMI Engineer'),
#   'jobDescription': rdflib.term.Literal("Engineers use mathematical and scientific principles to provide efficient solutions to technical problems. While scientists deliver scientific innovations, engineers are the ones who make these innovations useful for societal and consumer needs.\nEngineers are highly skilled specialists who use math and science to solve both simple and complex everyday problems. They make use of new discoveries by taking relevant information from prior scientific discoveries and finding where they apply to the more practical settings and uses. Engineers' valuable innovations strive to advance the way humans utilize products or perform tasks. Engineers are the professionals directly involved in the invention, design, and the maintenance of various machines, structures, or data systems.. . Engineers work with various objects and items, from massive construction project work sites to lending their expertise to development of the human genome. Often, they are responsible for the innovation and developments of new products or services, or a new type of technology or process. Engineers use science, technology, or math to solve problems and design machinery, build skyscrapers, and oversee public works. They also address society's needs and problems, including preserving clean water, development of drug delivery systems that work inside cells, or cleaning up oil spills. Engineers need a bachelor’s degree in engineering from a school accredited by the Accreditation Board for Engineering and Technology and must pass the Fundamentals of Engineering and the Principles and Practice of Engineering exams"),
#   'responsibility': rdflib.term.Literal('Development of new products such as helicopters, aero planes, toys, power plants, computers and chemicals\nSupervision of production in factories and testing products from factories to maintain quality standards\nEstimation of the time and price required to finish projects\nUse of computers to create and evaluate designs\nDetermination of the failures of components in factories'),
#   'annualSalary': rdflib.term.Literal('99467.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Chief Engineer/Project Manager'),
#   'jobDescription': None,
#   'responsibility': None,
#   'annualSalary': rdflib.term.Literal('99059.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Network Integration Engineer'),
#   'jobDescription': None,
#   'responsibility': None,
#   'annualSalary': rdflib.term.Literal('99081.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('MRB Liaison Engineer'),
#   'jobDescription': rdflib.term.Literal("Engineers use mathematical and scientific principles to provide efficient solutions to technical problems. While scientists deliver scientific innovations, engineers are the ones who make these innovations useful for societal and consumer needs.\nEngineers are highly skilled specialists who use math and science to solve both simple and complex everyday problems. They make use of new discoveries by taking relevant information from prior scientific discoveries and finding where they apply to the more practical settings and uses. Engineers' valuable innovations strive to advance the way humans utilize products or perform tasks. Engineers are the professionals directly involved in the invention, design, and the maintenance of various machines, structures, or data systems.. . Engineers work with various objects and items, from massive construction project work sites to lending their expertise to development of the human genome. Often, they are responsible for the innovation and developments of new products or services, or a new type of technology or process. Engineers use science, technology, or math to solve problems and design machinery, build skyscrapers, and oversee public works. They also address society's needs and problems, including preserving clean water, development of drug delivery systems that work inside cells, or cleaning up oil spills. Engineers need a bachelor’s degree in engineering from a school accredited by the Accreditation Board for Engineering and Technology and must pass the Fundamentals of Engineering and the Principles and Practice of Engineering exams"),
#   'responsibility': rdflib.term.Literal('Development of new products such as helicopters, aero planes, toys, power plants, computers and chemicals\nSupervision of production in factories and testing products from factories to maintain quality standards\nEstimation of the time and price required to finish projects\nUse of computers to create and evaluate designs\nDetermination of the failures of components in factories'),
#   'annualSalary': rdflib.term.Literal('99097.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Business Process Analyst/Engineer'),
#   'jobDescription': None,
#   'responsibility': None,
#   'annualSalary': rdflib.term.Literal('99163.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Service Sales Engineer'),
#   'jobDescription': rdflib.term.Literal("A sales engineer is an engineering professional who specializes in sales. These professionals act as consultants for their employing organization, making buying or selling decisions based on the technical aspects of a product. Sales engineers often work in B2B businesses, where they directly assist sales professionals in choosing the best products that meet the goals or needs of their business.\nSales engineers are in the business of selling advanced scientific and technical products to businesses and organizations. As a sales engineer, you have training in both engineering (or an industry-related science field) and sales. You envision, design and sell new products or programs you help develop in order to increase your clients' output and profit. Your job, as a knowledgeable sales engineer, is to negotiate product or service sales that would benefit your clients. Sales engineers work in many fields of production, including the technology, manufacturing and service industries.. . Most sales engineers must hold at least an Associate or bachelor's Degree in Engineering or another industry-related field. Two to four years of education are required to earn these degrees. You must be an expert in your industry in order to provide productive sales and happy customers. Sales engineers must also have strong organizational, critical and analytical thinking skills."),
#   'responsibility': rdflib.term.Literal('Prepare technical presentations to highlight the uses of a product to a potential customer\nEvaluate and determine the cost of products and highlight cost savings over time\nConsult with the sales team to understand company goals and make product recommendations\nAssist a team in researching and developing new technical products\nUse project management skills to plan the implementation of new products within a business\nMaintain technical and professional knowledge with continuing education and workshops'),
#   'annualSalary': rdflib.term.Literal('99277.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Aeronautical Engineer'),
#   'jobDescription': rdflib.term.Literal("Aeronautical engineers are tasked with designing, creating and maintaining travel mobiles as well as machines such as helicopters and airplane missiles. Using a combination of knowledge of aviation and technology, they create energy-efficient machines not only for defense systems but space exploration. Additionally, they create machines and technology with safety and environmental regulations in mind. Overall, aeronautical engineers specialize in flight mechanics, manufacturing and aerodynamics. Aeronautical engineers can be found working in such environments as airlines, armed forces and consultant agencies.\nAerospace engineers are responsible for designing and testing products that serve both the aeronautical and space industries. This role requires advanced materials knowledge and experience using specialized computer tools to draft designs for airplanes, helicopters, spacecraft, rockets, and other related machines.. . Aerospace engineers require a Bachelor's degree in aerospace engineering, mechanical engineering, physics, mathematics, or a similar science-based field of study. As many aerospace engineers work on government contracts, a security clearance is likely necessary. Security clearances can be acquired either through military service or through an employer. This role requires individuals with distinct math and other technical skills. Individuals should also be strongly detail-oriented."),
#   'responsibility': rdflib.term.Literal('Assessing the abilities of an aircraft or technology\nTesting products and modifying as needed\nCreating and implementing designs\nResearching and analyzing pertinent data\nDocumenting reports and writing manuals'),
#   'annualSalary': rdflib.term.Literal('99029.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))},
#  {'name': rdflib.term.Literal('Structural Engineer'),
#   'jobDescription': rdflib.term.Literal("Structural engineers work on physical structures as a subdiscipline of civil engineering. They provide technical advice to building contractors and architects to ensure that physical structures such as buildings, roads, tunnels and bridges are built with structural integrity that conform to set standards. The standards ensure compliance to withstanding external stress and environmental variations.\nA Structural Engineer is specialized in designing and analyzing various structures. They provide detailed calculations about the strength and stability of structures like bridges and buildings. A Structural Engineer will then collaborate with various departments from network engineers to support and operations to ensure a plan is in motion safely build the structure. A Structural Engineer works to balance various aspects of the project like safety to design. Additionally, a Structural Engineer researches advanced technology regarding best practices in the field and determines the most cost-effective solution.. . A Structural Engineer is generally located in the building industry and work alongside other professionals to meet create concepts to meet client needs. They usually begin as Civil Engineers and as they advance on their career path within the company will become promoted to the role. A bachelor's degree is required for the position, with many holding degrees in Civil Engineering or related engineering fields. Individuals with a firm holistic understanding of both the operational and physical aspects of projects tend to excel in this position."),
#   'responsibility': rdflib.term.Literal('Analyzing blueprints, reports, maps, reports, geological and topographical data\nPreparing designs, reports and drawings\nProviding technical advice on compliant designs and construction\nObtaining approvals for planning, design and regulation of buildings\nAnalyzing structure components and configurations\nInspecting and monitoring the work of contractors to ensure structural integrity is maintained'),
#   'annualSalary': rdflib.term.Literal('99065.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))}]

# %% [markdown]
# ## Skills that belong to category [CATEGORY]

# %%
def get_skills_in_category(category, graph):
    res = []

    query = """
        SELECT ?name 
        WHERE {{
            # ?skill a career:skill ;
                   schema:name ?name .
            # ?skill schema:category ?cat .
            # ?cat schema:object ?allCat .
            # ?allCat schema:name "{}" .
        }}
        GROUP BY ?skill
    """.format(category)

    qres = graph.query(query)
    for row in qres:
        res.append({"name": row.name})

    return res

get_skills_in_category("Economics", graph)
# Out:
# [{'name': rdflib.term.Literal('Market Structure')},
#  {'name': rdflib.term.Literal('Economic Forecasting')},
#  {'name': rdflib.term.Literal('Supply and Demand Modeling')},
#  {'name': rdflib.term.Literal('Economic Modeling')},
#  {'name': rdflib.term.Literal('Time Value Of Money')},
#  {'name': rdflib.term.Literal('Workforce Trends')},
#  {'name': rdflib.term.Literal('Economic Indicators')},
#  {'name': rdflib.term.Literal('Airline Economics')},
#  {'name': rdflib.term.Literal('Political Economy')},
#  {'name': rdflib.term.Literal('Techno Economic Analysis')},
#  {'name': rdflib.term.Literal('Labor Market Trends')},
#  {'name': rdflib.term.Literal('Food Economics')},
#  {'name': rdflib.term.Literal('Economic Research')},
#  {'name': rdflib.term.Literal('National Income')},
#  {'name': rdflib.term.Literal('Applied Economics')},
#  {'name': rdflib.term.Literal('Arbitrage Pricing Theories')},
#  {'name': rdflib.term.Literal('Business Cycle')},
#  {'name': rdflib.term.Literal('Business Economics')},
#  {'name': rdflib.term.Literal('Consumerism')},
#  {'name': rdflib.term.Literal('Development Economics')},
#  {'name': rdflib.term.Literal('Economics')},
#  {'name': rdflib.term.Literal('Econometrics')},
#  {'name': rdflib.term.Literal('Econometric Modeling')},
#  {'name': rdflib.term.Literal('Economic Analysis')},
#  {'name': rdflib.term.Literal('Economic Capital')},
#  {'name': rdflib.term.Literal('Economic Development')},
#  {'name': rdflib.term.Literal('Economic Growth')},
#  {'name': rdflib.term.Literal('Economic Order Quantity')},
#  {'name': rdflib.term.Literal('Economic Planning')},
#  {'name': rdflib.term.Literal('Economic Systems')},
#  {'name': rdflib.term.Literal('Economic Theories')},
#  {'name': rdflib.term.Literal('Economy')},
#  {'name': rdflib.term.Literal('Entrepreneurial Economics')},
#  {'name': rdflib.term.Literal('Financial Economics')},
#  {'name': rdflib.term.Literal('International Finance')},
#  {'name': rdflib.term.Literal('International Economics')},
#  {'name': rdflib.term.Literal('Labor Economics')},
#  {'name': rdflib.term.Literal('Macroeconomics')},
#  {'name': rdflib.term.Literal('Managerial Economics')},
#  {'name': rdflib.term.Literal('Supply And Demand')},
#  {'name': rdflib.term.Literal('Market Environment')},
#  {'name': rdflib.term.Literal('Microeconomics')},
#  {'name': rdflib.term.Literal('Monetary Economics')},
#  {'name': rdflib.term.Literal('Pharmacoeconomics')},
#  {'name': rdflib.term.Literal('Revaluation')},
#  {'name': rdflib.term.Literal('Transport Economics')},
#  {'name': rdflib.term.Literal('Urban Economics')},
#  {'name': rdflib.term.Literal('Deflation')},
#  {'name': rdflib.term.Literal('Trade Agreement')},
#  {'name': rdflib.term.Literal('Health Economics')}]

# %% [markdown]
# ## [Language/Non-language] skills

# %%
def get_lang_skills(isLang, graph):
    res = []
    query = """
        SELECT ?skill ?name
        WHERE {{
            # ?skill a career:skill ;
                   schema:name ?name ;
                   career:isLanguage {} .
        }}
    """.format(isLang)

    qres = graph.query(query)
    for row in qres:
        res.append({"name": row.name})
    return res

get_lang_skills("true", graph)
# Out:
# [{'name': rdflib.term.Literal('Swahili Language')},
#  {'name': rdflib.term.Literal('Bilingual (Spanish/English)')},
#  {'name': rdflib.term.Literal('Literary Translation')},
#  {'name': rdflib.term.Literal('Thai Language')},
#  {'name': rdflib.term.Literal('Albanian Language')},
#  {'name': rdflib.term.Literal('Serbo-Croatian Language')},
#  {'name': rdflib.term.Literal('Sinhalese Language')},
#  {'name': rdflib.term.Literal('Romanian Language')},
#  {'name': rdflib.term.Literal('Mongolian Language')},
#  {'name': rdflib.term.Literal('Estonian Language')},
#  {'name': rdflib.term.Literal('Marshallese Language')},
#  {'name': rdflib.term.Literal('Bosnian Language')},
#  {'name': rdflib.term.Literal('Hakka Language')},
#  {'name': rdflib.term.Literal('Kanuri Language')},
#  {'name': rdflib.term.Literal('Serbian Language')},
#  {'name': rdflib.term.Literal('Bulgarian Language')},
#  {'name': rdflib.term.Literal('Hausa Language')},
#  {'name': rdflib.term.Literal('Sign Language Interpretation')},
#  {'name': rdflib.term.Literal('Welsh Language')},
#  {'name': rdflib.term.Literal('Chechen Language')},
#  {'name': rdflib.term.Literal('Afrikaans Language')},
#  {'name': rdflib.term.Literal('Tongan Language')},
#  {'name': rdflib.term.Literal('Czech Language')},
#  {'name': rdflib.term.Literal('Uzbek Language')},
#  {'name': rdflib.term.Literal('Armenian Language')},
#  {'name': rdflib.term.Literal('Modern Greek')},
#  {'name': rdflib.term.Literal('Hawaiian Language')},
#  {'name': rdflib.term.Literal('Hungarian Language')},
#  {'name': rdflib.term.Literal('Azerbaijani Language')},
#  {'name': rdflib.term.Literal('Navajo Language')},
#  {'name': rdflib.term.Literal('Oromo Language')},
#  {'name': rdflib.term.Literal('Khandeshi Language')},
#  {'name': rdflib.term.Literal('Akkadian Language')},
#  {'name': rdflib.term.Literal('Amharic Language')},
#  {'name': rdflib.term.Literal('Aramaic Language')},
#  {'name': rdflib.term.Literal('Arem Language')},
#  {'name': rdflib.term.Literal('Awadhi Language')},
#  {'name': rdflib.term.Literal('Bagheli Language')},
#  {'name': rdflib.term.Literal('Bagri Language')},
#  {'name': rdflib.term.Literal('Indonesian Language')},
#  {'name': rdflib.term.Literal('Malay Language')},
#  {'name': rdflib.term.Literal('Malaysian Language')},
#  {'name': rdflib.term.Literal('Bambara Language')},
#  {'name': rdflib.term.Literal('Bangala Language')},
#  {'name': rdflib.term.Literal('Bardi Language')},
#  {'name': rdflib.term.Literal('Hebrew Language')},
#  {'name': rdflib.term.Literal('Latin Language')},
#  {'name': rdflib.term.Literal('Belarusian Language (Languages Of Belarus)')},
#  {'name': rdflib.term.Literal('Bemba Language (Bemba)')},
#  {'name': rdflib.term.Literal('Bhojpuri Language')},
#  {'name': rdflib.term.Literal('Biblical Hebrew')},
#  {'name': rdflib.term.Literal('Central Bikol Languages')},
#  {'name': rdflib.term.Literal('Bishnupriya Manipuri Language')},
#  {'name': rdflib.term.Literal('Bislama Language')},
#  {'name': rdflib.term.Literal('Brahui Language')},
#  {'name': rdflib.term.Literal('Cambodian Language')},
#  {'name': rdflib.term.Literal('Cebuano Language')},
#  {'name': rdflib.term.Literal('Chewa Language')},
#  {'name': rdflib.term.Literal('Classical Arabic')},
#  {'name': rdflib.term.Literal('Ancient Greek')},
#  {'name': rdflib.term.Literal('Classical Latin')},
#  {'name': rdflib.term.Literal('Classical Tibetan')},
#  {'name': rdflib.term.Literal('Computer-Assisted Translation')},
#  {'name': rdflib.term.Literal('Croatian Language')},
#  {'name': rdflib.term.Literal('Dagbani Language')},
#  {'name': rdflib.term.Literal('Danish Language')},
#  {'name': rdflib.term.Literal('Devanagari')},
#  {'name': rdflib.term.Literal('Dhatki Language')},
#  {'name': rdflib.term.Literal('Dogri Language')},
#  {'name': rdflib.term.Literal('Dzongkha')},
#  {'name': rdflib.term.Literal('Esperanto Language')},
#  {'name': rdflib.term.Literal('Faroese Language')},
#  {'name': rdflib.term.Literal('Fanagalo')},
#  {'name': rdflib.term.Literal('Filipino Language')},
#  {'name': rdflib.term.Literal('Finnish Language')},
#  {'name': rdflib.term.Literal('Flemish')},
#  {'name': rdflib.term.Literal('Min Nan')},
#  {'name': rdflib.term.Literal('Friulian Language')},
#  {'name': rdflib.term.Literal('Hokkien Language')},
#  {'name': rdflib.term.Literal('Fula Language')},
#  {'name': rdflib.term.Literal('Irish Language')},
#  {'name': rdflib.term.Literal('Garhwali Language')},
#  {'name': rdflib.term.Literal('Hindi Language')},
#  {'name': rdflib.term.Literal('Hindko Dialects')},
#  {'name': rdflib.term.Literal('Hmu Language')},
#  {'name': rdflib.term.Literal('Hong Kong Sign Language')},
#  {'name': rdflib.term.Literal('Ilokano Language')},
#  {'name': rdflib.term.Literal('Hiligaynon Language')},
#  {'name': rdflib.term.Literal('Mag-Indi Languages')},
#  {'name': rdflib.term.Literal('Jiba Language (Jukunoid Languages)')},
#  {'name': rdflib.term.Literal('Kamayo Language')},
#  {'name': rdflib.term.Literal('Kannada Language')},
#  {'name': rdflib.term.Literal('Kaonde Language')},
#  {'name': rdflib.term.Literal('Khariboli Dialect')},
#  {'name': rdflib.term.Literal('Kongo Language')},
#  {'name': rdflib.term.Literal('Kinyarwanda')},
#  {'name': rdflib.term.Literal('Kirundi')},
#  {'name': rdflib.term.Literal('Kodava Language')},
#  {'name': rdflib.term.Literal('Koine Greek')},
#  {'name': rdflib.term.Literal('Konkani Language')},
#  {'name': rdflib.term.Literal('Krio Language')},
#  {'name': rdflib.term.Literal('Kumaoni Language')},
#  {'name': rdflib.term.Literal('Kurmanji Kurdish')},
#  {'name': rdflib.term.Literal('Language Translation')},
#  {'name': rdflib.term.Literal('Latvian Language')},
#  {'name': rdflib.term.Literal('Levantine Arabic')},
#  {'name': rdflib.term.Literal('Lingala Language')},
#  {'name': rdflib.term.Literal('Luganda')},
#  {'name': rdflib.term.Literal('Gwere Language')},
#  {'name': rdflib.term.Literal('Soga Language')},
#  {'name': rdflib.term.Literal('Luxembourgish Language')},
#  {'name': rdflib.term.Literal('Magahi Language')},
#  {'name': rdflib.term.Literal('Maghrebi Arabic')},
#  {'name': rdflib.term.Literal('Malayalam Language')},
#  {'name': rdflib.term.Literal('Malvi Language')},
#  {'name': rdflib.term.Literal('Maninka Language')},
#  {'name': rdflib.term.Literal('Old French')},
#  {'name': rdflib.term.Literal('Medumba Language')},
#  {'name': rdflib.term.Literal('Tok Pisin')},
#  {'name': rdflib.term.Literal('Memoni Language')},
#  {'name': rdflib.term.Literal('Mewari Language')},
#  {'name': rdflib.term.Literal('Montenegrin Language')},
#  {'name': rdflib.term.Literal('Munda Languages')},
#  {'name': rdflib.term.Literal('Mwan Language')},
#  {'name': rdflib.term.Literal('Mwanga Language')},
#  {'name': rdflib.term.Literal('Nawayathi Dialect')},
#  {'name': rdflib.term.Literal('Nehan (Languages Of The Solomon Islands)')},
#  {'name': rdflib.term.Literal('Nimadi Language')},
#  {'name': rdflib.term.Literal('Norwegian Languages')},
#  {'name': rdflib.term.Literal('Oriya Language')},
#  {'name': rdflib.term.Literal('Okanagan Languages')},
#  {'name': rdflib.term.Literal('Old Norse')},
#  {'name': rdflib.term.Literal('Palestinian Arabic')},
#  {'name': rdflib.term.Literal('Pamona Language')},
#  {'name': rdflib.term.Literal('Pangasinan Language')},
#  {'name': rdflib.term.Literal('Papiamento')},
#  {'name': rdflib.term.Literal('Pashto Language')},
#  {'name': rdflib.term.Literal('Tagalog Language')},
#  {'name': rdflib.term.Literal('Polish Language')},
#  {'name': rdflib.term.Literal('Prakrit')},
#  {'name': rdflib.term.Literal('Pulaar Language')},
#  {'name': rdflib.term.Literal('Pular Language')},
#  {'name': rdflib.term.Literal('Punjabi Dialects')},
#  {'name': rdflib.term.Literal('Punjabi Language')},
#  {'name': rdflib.term.Literal('Rajasthani Language')},
#  {'name': rdflib.term.Literal('Bonda Languages')},
#  {'name': rdflib.term.Literal('Sanskrit')},
#  {'name': rdflib.term.Literal('Northern Sotho Languages')},
#  {'name': rdflib.term.Literal('Sotho Language')},
#  {'name': rdflib.term.Literal('Tswana Language')},
#  {'name': rdflib.term.Literal('Shona Language')},
#  {'name': rdflib.term.Literal('Sindhi Language')},
#  {'name': rdflib.term.Literal('Singaporean Hokkien')},
#  {'name': rdflib.term.Literal('Singlish')},
#  {'name': rdflib.term.Literal('Swazi Language')},
#  {'name': rdflib.term.Literal('Slovak Language')},
#  {'name': rdflib.term.Literal('Slovenian Language')},
#  {'name': rdflib.term.Literal('Surajpuri Language')},
#  {'name': rdflib.term.Literal('Swedish Language')},
#  {'name': rdflib.term.Literal('Unary Language')},
#  {'name': rdflib.term.Literal('Berber Languages')},
#  {'name': rdflib.term.Literal('Tamil Languages')},
#  {'name': rdflib.term.Literal('Surigaonon Language')},
#  {'name': rdflib.term.Literal('Tausug Language')},
#  {'name': rdflib.term.Literal('Technical Translation')},
#  {'name': rdflib.term.Literal('Telugu Language')},
#  {'name': rdflib.term.Literal('Tetum Language')},
#  {'name': rdflib.term.Literal('Tigrinya Language')},
#  {'name': rdflib.term.Literal('Tuwali Language')},
#  {'name': rdflib.term.Literal('Ukrainian Language')},
#  {'name': rdflib.term.Literal('Urdu Language')},
#  {'name': rdflib.term.Literal('Veps Language')},
#  {'name': rdflib.term.Literal('Visayan Languages')},
#  {'name': rdflib.term.Literal('Valman Languages')},
#  {'name': rdflib.term.Literal('Guamo Languages')},
#  {'name': rdflib.term.Literal('Wolof Languages')},
#  {'name': rdflib.term.Literal('Ibanag Language')},
#  {'name': rdflib.term.Literal('Yiddish Language')},
#  {'name': rdflib.term.Literal('Sakha (Language)')},
#  {'name': rdflib.term.Literal('Berber (Language)')},
#  {'name': rdflib.term.Literal('Mizo (Language)')},
#  {'name': rdflib.term.Literal('Ewondo (Language)')},
#  {'name': rdflib.term.Literal('Igbo (Language)')},
#  {'name': rdflib.term.Literal('Frisian (Language)')},
#  {'name': rdflib.term.Literal('Chamorro (Language)')},
#  {'name': rdflib.term.Literal('Sogdian (Language)')},
#  {'name': rdflib.term.Literal('Manipuri (Language)')},
#  {'name': rdflib.term.Literal('Koma (Language)')},
#  {'name': rdflib.term.Literal('Ubi (Language)')},
#  {'name': rdflib.term.Literal('Chango (Language)')},
#  {'name': rdflib.term.Literal('Bahasa (Language)')},
#  {'name': rdflib.term.Literal('Swabian German (Language)')},
#  {'name': rdflib.term.Literal('Mayan (Language)')},
#  {'name': rdflib.term.Literal('Kalenjin (Language)')},
#  {'name': rdflib.term.Literal('Korwa (Language)')},
#  {'name': rdflib.term.Literal('Bunu (Language)')},
#  {'name': rdflib.term.Literal('Anam (Language)')},
#  {'name': rdflib.term.Literal('Lango (Language)')},
#  {'name': rdflib.term.Literal('Wagdi (Language)')},
#  {'name': rdflib.term.Literal('Kachin (Language)')},
#  {'name': rdflib.term.Literal('Ndebele (Language)')},
#  {'name': rdflib.term.Literal('Attached Proton Test')},
#  {'name': rdflib.term.Literal('Tripuri (Language)')},
#  {'name': rdflib.term.Literal('Quecha (Language)')},
#  {'name': rdflib.term.Literal('Carew (Language)')},
#  {'name': rdflib.term.Literal('Haya (Language)')},
#  {'name': rdflib.term.Literal('Silesian (Language)')},
#  {'name': rdflib.term.Literal('Marathi (Language)')},
#  {'name': rdflib.term.Literal('Tulu (Language)')},
#  {'name': rdflib.term.Literal('Duala (Language)')},
#  {'name': rdflib.term.Literal('Kwa (Language)')},
#  {'name': rdflib.term.Literal('Shan (Language)')},
#  {'name': rdflib.term.Literal('Lule (Language)')},
#  {'name': rdflib.term.Literal('Akan (Language)')},
#  {'name': rdflib.term.Literal('Carib (Language)')},
#  {'name': rdflib.term.Literal('Batak (Language)')},
#  {'name': rdflib.term.Literal('Tibetan (Language)')},
#  {'name': rdflib.term.Literal('Garifuna (Language)')},
#  {'name': rdflib.term.Literal('Azari (Language)')},
#  {'name': rdflib.term.Literal('Ainu (Language)')},
#  {'name': rdflib.term.Literal('Fali (Language)')},
#  {'name': rdflib.term.Literal('Waziri (Language)')},
#  {'name': rdflib.term.Literal('Bengali (Language)')},
#  {'name': rdflib.term.Literal('Sudanese (Language)')},
#  {'name': rdflib.term.Literal('Kikuyu (Language)')},
#  {'name': rdflib.term.Literal('Dayi (Language)')},
#  {'name': rdflib.term.Literal('Ladino (Language)')},
#  {'name': rdflib.term.Literal('Swati (Language)')},
#  {'name': rdflib.term.Literal('Kurukh (Language)')},
#  {'name': rdflib.term.Literal('Catalan (Language)')},
#  {'name': rdflib.term.Literal('Kayan (Language)')},
#  {'name': rdflib.term.Literal('Chakma (Language)')},
#  {'name': rdflib.term.Literal('Saraiki (Language)')},
#  {'name': rdflib.term.Literal('Nepali (Language)')},
#  {'name': rdflib.term.Literal('Santhali (Language)')},
#  {'name': rdflib.term.Literal('Sumerian (Language)')},
#  {'name': rdflib.term.Literal('Tamil (Language)')},
#  {'name': rdflib.term.Literal('Bassa (Language)')},
#  {'name': rdflib.term.Literal('Seim (Language)')},
#  {'name': rdflib.term.Literal('Dari (Language)')},
#  {'name': rdflib.term.Literal('Ovambo (Language)')},
#  {'name': rdflib.term.Literal('Benga (Language)')},
#  {'name': rdflib.term.Literal('Manx (Language)')},
#  {'name': rdflib.term.Literal('Hup (Language)')},
#  {'name': rdflib.term.Literal('Lawa (Language)')},
#  {'name': rdflib.term.Literal('Shama (Language)')},
#  {'name': rdflib.term.Literal('Xhosa (Language)')},
#  {'name': rdflib.term.Literal('Gaelic (Language)')},
#  {'name': rdflib.term.Literal('Dinka (Language)')},
#  {'name': rdflib.term.Literal('Aymara (Language)')},
#  {'name': rdflib.term.Literal('Gujarati (Language)')},
#  {'name': rdflib.term.Literal('Galo (Language)')},
#  {'name': rdflib.term.Literal('Gikuyu (Language)')},
#  {'name': rdflib.term.Literal('Hopi (Language)')},
#  {'name': rdflib.term.Literal('Sango (Language)')},
#  {'name': rdflib.term.Literal('Kurdish (Language)')},
#  {'name': rdflib.term.Literal('Tharu (Language)')},
#  {'name': rdflib.term.Literal('Yoruba (Language)')},
#  {'name': rdflib.term.Literal('Dhivehi (Language)')},
#  {'name': rdflib.term.Literal('Phoenician (Language)')},
#  {'name': rdflib.term.Literal('Maithili (Language)')},
#  {'name': rdflib.term.Literal('Written English')},
#  {'name': rdflib.term.Literal('Braille Literacy')},
#  {'name': rdflib.term.Literal('Haitian Creole')},
#  {'name': rdflib.term.Literal('Somali Language')},
#  {'name': rdflib.term.Literal('Vietnamese Language')},
#  {'name': rdflib.term.Literal('Dutch Language')},
#  {'name': rdflib.term.Literal('Cantonese Chinese')},
#  {'name': rdflib.term.Literal('Lithuanian Language')},
#  {'name': rdflib.term.Literal('Latin')},
#  {'name': rdflib.term.Literal('Turkish Language')},
#  {'name': rdflib.term.Literal('Burmese Language')},
#  {'name': rdflib.term.Literal('Khmer Language')},
#  {'name': rdflib.term.Literal('Multilingualism')},
#  {'name': rdflib.term.Literal('German Language')},
#  {'name': rdflib.term.Literal('French Language')},
#  {'name': rdflib.term.Literal('Russian Language')},
#  {'name': rdflib.term.Literal('Italian Language')},
#  {'name': rdflib.term.Literal('Mandarin Chinese')},
#  {'name': rdflib.term.Literal('Korean Language')},
#  {'name': rdflib.term.Literal('American Sign Language (ASL)')},
#  {'name': rdflib.term.Literal('Farsi Language')},
#  {'name': rdflib.term.Literal('Arabic Language')},
#  {'name': rdflib.term.Literal('Sign Languages')},
#  {'name': rdflib.term.Literal('Japanese Language')},
#  {'name': rdflib.term.Literal('Assamese')},
#  {'name': rdflib.term.Literal('Spanish Language')},
#  {'name': rdflib.term.Literal('Portuguese Language')},
#  {'name': rdflib.term.Literal('English Language')}]

# %% [markdown]
# ## [Software/Non-software] skills

# %%
def get_software_skills(sw, graph):
    res = []

    query = """
        SELECT ?skill ?name
        WHERE {{
            # ?skill a career:skill ;
                   schema:name ?name ;
                   career:isSoftware {} .
        }}
    """.format(sw)

    qres = graph.query(query)
    for row in qres:
        res.append({"name": row.name})
    return json.dumps(res)

get_software_skills("true", graph)
# Out:
# '[{"name": "Microsoft Sysprep"}, {"name": "Cloud Security Applications"}, {"name": "Odoo 10"}, {"name": "Microsoft Simplygon"}, {"name": "QualysGuard"}, {"name": "Fastpath (Software)"}, {"name": "Oracle Retail"}, {"name": "InteliChart"}, {"name": "HCL AppScan"}, {"name": "IBM Initiate"}, {"name": "Kendo UI Mobile"}, {"name": "Bentley LumenRT"}, {"name": "MobX"}, {"name": "Oracle Audit Vault"}, {"name": "SciDB"}, {"name": "Content Manager OnDemand (CMOD)"}, {"name": "DISA Gold Disk"}, {"name": "Symantec Altiris"}, {"name": "Paint Tool SAI"}, {"name": "Vizor.Io"}, {"name": "MockK"}, {"name": "Mapping Software"}, {"name": "NgRx Effects"}, {"name": "JD Edwards World"}, {"name": "Poppulo"}, {"name": "SkyKick"}, {"name": "Kochava"}, {"name": "mlpack (C++ Library)"}, {"name": "Medflow EMR"}, {"name": "NetSuite Financials"}, {"name": "Firebase Security"}, {"name": "Financial Aid Software"}, {"name": "ES6 Module Loader"}, {"name": "Oracle Configure-Price-Quote (CPQ)"}, {"name": "NetIQ"}, {"name": "Oracle Procurement"}, {"name": "IBM Operational Decision Manager (ODM)"}, {"name": "Redux-Saga"}, {"name": "Clip Studio Paint"}, {"name": "Nvidia Jetson"}, {"name": "Universal Image Loader"}, {"name": "Dell EMC UniSphere"}, {"name": "Clarabridge (Software)"}, {"name": "SAS Enterprise Miner"}, {"name": "Onsen UI"}, {"name": "NgRx Store"}, {"name": "Encoder Pro"}, {"name": "Google Keyword Planner"}, {"name": "Stripe Connect"}, {"name": "VivaVideo"}, {"name": "InMoment"}, {"name": "UserZoom GO"}, {"name": "Tax Software"}, {"name": "Peoplesoft nVision"}, {"name": "Spring Cloud Config"}, {"name": "Life 70 (Software)"}, {"name": "Cordova Plugins"}, {"name": "Oracle Javascript Extension Toolkit (JET)"}, {"name": "HP 3Par"}, {"name": "UIViewController"}, {"name": "Eggplant Functional"}, {"name": "Synthesio"}, {"name": "Shell Commands"}, {"name": "Industrial Control Software"}, {"name": "3M Encoder"}, {"name": "HackerOne"}, {"name": "Sprout Social"}, {"name": "Resilient Distributed Datasets (RDD) Programming"}, {"name": "FlexSlider"}, {"name": "IdentityServer4"}, {"name": "IBM Mobile"}, {"name": "Archivists\' Toolkit"}, {"name": "getView"}, {"name": "NgRx (Framework)"}, {"name": "Web Audio API"}, {"name": "MassLynx"}, {"name": "OrmLite Servicestack"}, {"name": "WatiN"}, {"name": "GoCAD"}, {"name": "TriZetto Facets"}, {"name": "3M (Software)"}, {"name": "Database Software"}, {"name": "Siemens Invision"}, {"name": "TestStand"}, {"name": "Presagis Creator"}, {"name": "FundEZ"}, {"name": "Design Software"}, {"name": "Apttus"}, {"name": "GE iFix"}, {"name": "EarlGrey (Software)"}, {"name": "ViewModel"}, {"name": "Sales Automation Software"}, {"name": "OCLC Connexion"}, {"name": "EMC Avamar"}, {"name": "Indegy"}, {"name": "Advent Geneva"}, {"name": "IBM Sterling B2B Integrator"}, {"name": "IBM Worklight"}, {"name": "SIS AdvantX"}, {"name": "UITableView"}, {"name": "Microsoft Test Manager"}, {"name": "PinkSoft FStorm"}, {"name": "DeBabelizer"}, {"name": "Ember Data"}, {"name": "DataStax Enterprise Graph"}, {"name": "Oracle Identity Analytics"}, {"name": "LabWare LIMS (Software)"}, {"name": "AppSense"}, {"name": "WebCIS"}, {"name": "RSA SecurID"}, {"name": "SAP Information Steward"}, {"name": "Troux (Enterprise Architecture Software)"}, {"name": "Heartbleed Bug"}, {"name": "ZenHub"}, {"name": "QAD Cloud ERP"}, {"name": "Wise Package Studio"}, {"name": "Oracle Accounts Payable"}, {"name": "MarinOne (Software)"}, {"name": "Watson LIMS"}, {"name": "SAS Business Intelligence (BI)"}, {"name": "BirchStreet Software"}, {"name": "WebMethods"}, {"name": "SeeTest"}, {"name": "TrackWise"}, {"name": "Shopify App"}, {"name": "ADP PayForce"}, {"name": "Google Identity Toolkit"}, {"name": "Snap Lens Studio"}, {"name": "Marmoset Toolbag"}, {"name": "OSI Monarch"}, {"name": "ATG Dynamo"}, {"name": "Micrografx"}, {"name": "Nuxt.Js"}, {"name": "Oracle Field Service"}, {"name": "Amazon Lumberyard"}, {"name": "Xsens"}, {"name": "Tridion Content Delivery"}, {"name": "UNIGINE Engin ...

# %%
query = """
        SELECT ?name
        WHERE {{
            career_title:ET0006B003DE68AD96 schema:type schema:Occupation ;
                schema:name ?name .
        }}
    """
    
qres = graph.query(query)
for row in qres:
    print(row.name)
# Out:
# Service Center Clerk
